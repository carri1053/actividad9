# %% [markdown]
# # Actividad 9
# # 🔍 Parte 1: Análisis de Lagos Argentinos con Python
# Objetivo: Repasar manipulación de datos con Pandas e introducir valores nulos y mapas con Folium.

# %% [markdown]
# #  La información de nuestros datos
# * ¿Cómo comunicamos la información analizada sobre los datos?
# * ¿Cómo conocemos la composición de los datos?
# * ¿Qué recursos podemos usar para comunicar los resultados de los análisis?:
#     * Cantidad de lagos por provincia.
#     * Cantidad de lagos por tamaño.

# %% [markdown]
# # ✅ Etapa 1: Exploración Básica (10 min)
# * Consigna 1: Cargá el dataset y utiliza las operaciones básicas para conocer el contenido del dataset:
# * [Lagos Argentinos](https://archivos.linti.unlp.edu.ar/index.php/s/LBNPS7EdmNSwt8z).
#     * Nombre del archivo: lagos_arg.csv
#     * Descargado de: https://www.ign.gob.ar/NuestrasActividades/Geografia/DatosArgentina/Lagos
# * Cantidad de filas y columans
# * Nombres de las columnas
# * Tipos de datos de las columnas
# * Ver las primeras 10 filas del dataset

# %% [markdown]
# ## La cantidad de filas y columnas del dataset

# %%
import pandas as pd
lagos=pd.read_csv("lagos.csv")

# %%
lagos.shape
# Out:
# (52, 11)

# %% [markdown]
# ## Nombres de las columnas

# %%
lagos.columns
# Out:
# Index(['Nombre', 'Ubicación', 'Superficie (km²)', 'Profundidad máxima (m)',
#        'Profundidad media (m)', 'Coordenadas', 'Sup Tamaño', 'Latitud en GMS',
#        'Longitud en GMS', 'lat', 'lng'],
#       dtype='object')

# %% [markdown]
# ## Tipo de datos de las columnas

# %%
lagos.dtypes
# Out:
# Nombre                     object
# Ubicación                  object
# Superficie (km²)            int64
# Profundidad máxima (m)    float64
# Profundidad media (m)     float64
# Coordenadas                object
# Sup Tamaño                 object
# Latitud en GMS             object
# Longitud en GMS            object
# lat                       float64
# lng                       float64
# dtype: object

# %% [markdown]
# ## Primeras 10 filas del dataset

# %%
lagos.head(10)
# Out:
#                Nombre            Ubicación  Superficie (km²)  \
# 0      Lago Argentino           Santa Cruz              1435
# 1         Lago Viedma           Santa Cruz              1166
# 2   Lago Nahuel Huapi  Río Negro / Neuquén               540
# 3        Lago Musters               Chubut               427
# 4        Lago Cardiel           Santa Cruz               358
# 5        Lago Epecuén         Buenos Aires               156
# 6     Lago Pellegrini            Río Negro               116
# 7        Lago Strobel           Santa Cruz               100
# 8        Lago Fontana               Chubut                84
# 9  Lago Huechulafquen              Neuquén                84
#
#    Profundidad máxima (m)  Profundidad media (m)            Coordenadas  \
# 0                   500.0                  150.0  50°14'53"S 72°38'43"O
# 1                     NaN                    NaN  49°37'27"S 72°29'42"O
# 2                   464.0                  157.0  40°51'16"S 71°36'58"O
# 3                    39.0                   20.0  45°24'53"S 69°11'52"O
# 4                     NaN                   49.0   48°55'3"S 71°12'53"O
# 5                    11.0                    7.0   37°7'45"S 62°51'53"O
# 6                     NaN                    NaN  38°42'25"S 67°58'23"O
# 7                     NaN                    NaN  48°25'58"S 71°11'25"O
# 8                     NaN                   79.0  44°55'17"S 71°29'45"O
# 9                     NaN                  142.0  39°46'28"S 71°30'32"O
#
#   Sup Tamaño Latitud en GMS Longitud en GMS        lat        lng
# 0     grande     50°14'53"S      72°38'43"O -50.248056 -72.645278
# 1     grande     49°37'27"S      72°29'42"O -49.624167 -72.495000
# 2     grande     40°51'16"S      71°36'58"O -40.854444 -71.616111
# 3     grande     45°24'53"S      69°11'52"O -45.414722 -69.197778
# 4     grande      48°55'3"S      71°12'53"O -48.917500 -71.214722
# 5     grande      37°7'45"S      62°51'53"O -37.129167 -62.864722
# 6     grande     38°42'25"S      67°58'23"O -38.706944 -67.973056
# 7     grande     48°25'58"S      71°11'25"O -48.432778 -71.190278
# 8     grande     44°55'17"S      71°29'45"O -44.921389 -71.495833
# 9     grande     39°46'28"S      71°30'32"O -39.774444 -71.508889

# %% [markdown]
# # ✅ Etapa 2: Análisis por Provincia (15 min)
# * ¿En qué provincias hay lagos?
# * Cantidad de Lagos por provincia.
# * Gráfico de torta sobre la cantidad de lagos provincia.
# * Gráfico de barra sobre la cantidad de lagos provincia.

# %% [markdown]
# ## Cantidad de Lagos por provincia

# %%
lagos["Ubicación"].value_counts()
# Out:
# Ubicación
# Santa Cruz                                               16
# Neuquén                                                  14
# Chubut                                                   13
# Río Negro                                                 4
# Tierra del Fuego, Antártida e Islas del Atlántico Sur     3
# Río Negro / Neuquén                                       1
# Buenos Aires                                              1
# Name: count, dtype: int64

# %% [markdown]
# ## Gráfico de torta sobre la cantidad de lagos provincia

# %%
import plotly.express as px

# %%
provincia = lagos["Ubicación"].value_counts()

# %%
px.pie(data_frame = provincia, values = provincia.values, names = provincia.index, title = "cantidad de lagos").show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="db8eefc5-a1cd-4103-9382-3f1a7d2207a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db8eefc5-a1cd-4103-9382-3f1a7d2207a3")) {                    Plotly.newPlot(                        "db8eefc5-a1cd-4103-9382-3f1a7d2207a3",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Ubicación=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Santa Cruz","Neuquén","Chubut","Río Negro","Tierra del Fuego, Antártida e Islas del Atlántico Sur","Buenos Aires"],"legendgroup":"","name":"","showlegend":true,"values":[16,15,13,4,3,1],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpol ...

# %% [markdown]
# ## Gráfico de barra sobre la cantidad de lagos provincia

# %%
fig = px.bar(x=provincia.index, y=provincia.values, title="cantidad de lagos por provincia")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1e76c3fd-f4fc-47dc-87f3-cdbc897ee701" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e76c3fd-f4fc-47dc-87f3-cdbc897ee701")) {                    Plotly.newPlot(                        "1e76c3fd-f4fc-47dc-87f3-cdbc897ee701",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Santa Cruz","Neuquén","Chubut","Río Negro","Tierra del Fuego, Antártida e Islas del Atlántico Sur","Buenos Aires"],"xaxis":"x","y":[16,15,13,4,3,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo ...

# %% [markdown]
# ## ¿En qué provincias hay lagos?

# %%
print(lagos["Ubicación"].unique())
# Out:
# ['Santa Cruz' 'Neuquén' 'Chubut' 'Buenos Aires' 'Río Negro'
#  'Tierra del Fuego, Antártida e Islas del Atlántico Sur']

# %% [markdown]
# # ✅ Etapa 3: Filtrar y Limpiar Datos (15 min)
# * Mostrar los lagos que son de la provincia de Neuquén. **Nota**: no te olvides de incluir el lago que está compartido con otra provincia, (isin(["Neuquén", "Río Negro / Neuquén"])]
# * Mostrar cómo modificaríamos si nos piden  reemplazar el valor de 'Río Negro / Neuquén' **por** 'Neuquén'?
# * Filtrá los lagos de Chubut con superficie menor a 10 km². **Nota**: dataframe[(condición1) & (condición2)]

# %% [markdown]
# ### Mostrar los lagos que son de la provincia de Neuquén

# %%
lagos_neuquen = lagos[lagos ["Ubicación"].isin(["Neuquén", "Río Negro / Neuquén"])]
lagos_neuquen
# Out:
#                 Nombre Ubicación  Superficie (km²)  Profundidad máxima (m)  \
#
# * ¿Qué podemos analizar sobre los valores de la profundidad máxima y media de los lagos?
# * ¿Entre qué valores están ambas mediciones? **Nota**: describe().
# * Realicemos un gráfico de barras para comparar **Profundidad máxima** y **Profundidad media** de los lagos.
#
# * ¿Hay valores nulos? **Nota**: info().
# * Investigar sobre gráficos tipo scatter o dispersión.

# %% [markdown]
# ## ¿Qué podemos analizar sobre los valores de la profundidad máxima y media de los lagos?

# %%
# Out:
#     Profundidad máxima (m)  Profundidad media (m)
# 0                    500.0                  150.0
# 1                      NaN                    NaN
# 2                    464.0                  157.0
# 3                     39.0                   20.0
# 4                      NaN                   49.0
# 5                     11.0                    7.0
# 6                      NaN                    NaN
# 7                      NaN                    NaN
# 8                      NaN                   79.0
# 9                      NaN                  142.0
# 10                     NaN                    NaN
# 11                     NaN                    NaN
# 12                     NaN                    NaN
# 13                   287.0                  149.0
# 14                   165.0                   64.0
# 15                   277.0                  166.0
# 16                     NaN                   43.0
# 17                     NaN                    NaN
# 18                   180.0                  111.0
# 19                     NaN                    NaN
# 20                     NaN                    NaN
# 21                   168.0                  101.0
# 22                     NaN                   31.0
# 23                     NaN                    NaN
# 24                   218.0                  111.0
# 25                     NaN                    NaN
# 26                     NaN                    NaN
# 27                     NaN                    NaN
# 28                     NaN                    NaN
# 29                     NaN                   69.0
# 30                     NaN                    NaN
# 31                     NaN                    NaN
# 32                     NaN                    NaN
# 33                   147.0                  104.0
# 34                     NaN                    NaN
# 35                     NaN                    NaN
# 36                     NaN                    NaN
# 37                     NaN                    NaN
# 38                   148.0                   92.0
# 39                   111.0                   80.0
# 40                   108.0                   49.0
# 41                     NaN                   66.0
# 42                     NaN                    NaN
# 43                     NaN                    NaN
# 44                     NaN                    NaN
# 45                     NaN                    NaN
# 46                     NaN                    NaN
# 47                     NaN                    NaN
# 48                     NaN                    NaN
# 49                     NaN                    NaN
# 50                     NaN                    NaN
# 51                    57.0                   25.0

# %% [markdown]
# ##  ¿Entre qué valores están ambas mediciones?

# %%
print(lagos[['Profundidad máxima (m)', 'Profundidad media (m)']].describe())
# Out:
#        Profundidad máxima (m)  Profundidad media (m)
# count                15.00000              22.000000
# mean                192.00000              84.772727
# std                 141.21817              47.625455
# min                  11.00000               7.000000
# 25%                 109.50000              49.000000
# 50%                 165.00000              79.500000
# 75%                 247.50000             111.000000
# max                 500.00000             166.000000

# %% [markdown]
# ## Realicemos un gráfico para comparar **Profundidad máxima** y **Profundidad media** de los lagos.

# %%
import plotly.express as px
fig = px.bar(lagos,
             x="Nombre",
             y=['Profundidad máxima (m)', 'Profundidad media (m)'],
             barmode='group',
             title="Comparación de Profundidades de Lagos",
             labels={"value": "Metros", "variable": "Tipo de Profundidad"},
             color_discrete_sequence=["#1E90FF", "#00BFFF"])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cd0bab06-781f-41bb-9928-63904ae0e0dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd0bab06-781f-41bb-9928-63904ae0e0dc")) {                    Plotly.newPlot(                        "cd0bab06-781f-41bb-9928-63904ae0e0dc",                        [{"alignmentgroup":"True","hovertemplate":"Tipo de Profundidad=Profundidad máxima (m)\u003cbr\u003eNombre=%{x}\u003cbr\u003eMetros=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"
columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Nombre                  52 non-null     object
#  1   Ubicación               52 non-null     object
#  2   Superficie (km²)        52 non-null     int64
#  3   Profundidad máxima (m)  15 non-null     float64
#  4   Profundidad media (m)   22 non-null     float64
#  5   Coordenadas             52 non-null     object
#  6   Sup Tamaño              52 non-null     object
#  7   Latitud en GMS          52 non-null     object
#  8   Longitud en GMS         52 non-null     object
#  9   lat                     52 non-null     float64
#  10  lng                     52 non-null     float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 4.6+ KB

# %% [markdown]
# ## Gráfico de dispersión

# %% [markdown]
# ¿Qué datos compara este gráfico?

# %%
fig = px.scatter(lagos,
                 x="Profundidad media (m)",
                 y="Superficie (km²)",

                 title="Relación: Profundidad Media vs. Superficie")

fig.update_traces(textposition='top center', marker=dict(size=12))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0ed14313-7557-4896-a0e1-c9e9ed578dd8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ed14313-7557-4896-a0e1-c9e9ed578dd8")) {                    Plotly.newPlot(                        "0ed14313-7557-4896-a0e1-c9e9ed578dd8",                        [{"hovertemplate":"Profundidad media (m)=%{x}\u003cbr\u003eSuperficie (km²)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","size":12},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[150.0,null,157.0,20.0,49.0,7.0,null,null,79.0,142.0,null,null,null,149.0,64.0,166.0,43.0,null,111.0,null,null,101.0,31.0,null,111.0,null,null,null,null,69.0,null,null,null,104.0,null,null,null,null,92.0,80.0,49.0,66.0,null,null,null,null,null,null,null,null,null,25.0],"xaxis":"x","y":[1435,1166,540,427,358,156,116,100,84,84,78,73,65,58,58,53,49,47,47,42,42,42,41,40,39,38,37,37,30,29,28,26,23,23,21,20,20,20,17,17,17,16,16,14,14,14,12,12,11,10,10,10],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{" ...

# %% [markdown]
# Modificar el gráfico para que compare la longitud y la Superficie.

# %%
lagos.columns
# Out:
# Index(['Nombre', 'Ubicación', 'Superficie (km²)', 'Profundidad máxima (m)',
#        'Profundidad media (m)', 'Coordenadas', 'Sup Tamaño', 'Latitud en GMS',
#        'Longitud en GMS', 'lat', 'lng'],
#       dtype='object')

# %%
fig = px.scatter(lagos,
                 x="Longitud en GMS",
                 y="Superficie (km²)",

                 title="Relación: Longitud en GMS vs. Superficie")

fig.update_traces(textposition='top center', marker=dict(size=12))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="44f25eb5-4d70-4c9b-a934-6edd165b4948" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44f25eb5-4d70-4c9b-a934-6edd165b4948")) {                    Plotly.newPlot(                        "44f25eb5-4d70-4c9b-a934-6edd165b4948",                        [{"hovertemplate":"Longitud en GMS=%{x}\u003cbr\u003eSuperficie (km²)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","size":12},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["72°38'43\"O","72°29'42\"O","71°36'58\"O","69°11'52\"O","71°12'53\"O","62°51'53\"O","67°58'23\"O","71°11'25\"O","71°29'45\"O","71°30'32\"O","71°24'55\"O","71°49'12\"O","71°31'49\"O","71°51'45\"O","71°7'35\"O","71°26'11\"O","67°42'55\"O","71°33'3\"O","71°38'59\"O","72°21'11\"O","72°8'34\"O","71°40'31\"O","71°49'55\"O","71°42'40\"O","71°32'52\"O","67°35'36\"O","71°36'48\"O","71°32'11\"O","72°1'2\"O","71°26'52\"O","71°13'25\"O","71°18'52\"O","71°28'13\"O","71°39'59\"O","71°16'26\"O","71°39'35\"O","68°32'52\"O","71°35'5\"O","71°30'24\"O","71°25'13\"O","71°40'9\"O","71°35'2\"O","72°16'13\"O","72°12'9\"O","73°20'59\"O","71°19'10\"O","71°32'28\"O","71°30'27\"O","71°28'33\"O","71°30'8\"O","65°48'23\"O","71°20'48\"O"],"xaxis":"x","y":[1435,1166,540,427,358,156,116,100,84,84,78,73,65,58,58,53,49,47,47,42,42,42,41,40,39,38,37,37,30,29,28,26,23,23,21,20,20,20,17,17,17,16,16,14,14,14,12,12,11,10,10,10],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222 ...

# %% [markdown]
# # ✅ Etapa 5: Visualización con Mapas (15 min)
# * Otro recurso para visualizar datos geolocalizados son los mapas.
# * Mostrar todos los lagos en un mapa.
# * Mostrar los lagos de Chubut solamente.
# * Mostrar los lagos con color según su tamaño.
# * Mostrar los datos de otro dataset.

# %% [markdown]
# ## La librería folium nos permite mostrar datos en mapas

# %%
import folium

# %% [markdown]
# * ¿Qué datos nos indican un punto geográfico en un mapa?
# * ¿En qué columnas están estos datos?

# %%
lat=lagos["lat"].head(10)
lat
# Out:
# 0   -50.248056
# 1   -49.624167
# 2   -40.854444
# 3   -45.414722
# 4   -48.917500
# 5   -37.129167
# 6   -38.706944
# 7   -48.432778
# 8   -44.921389
# 9   -39.774444
# Name: lat, dtype: float64

# %%
ing=lagos["lng"].head(10)
ing
# Out:
# 0   -72.645278
# 1   -72.495000
# 2   -71.616111
# 3   -69.197778
# 4   -71.214722
# 5   -62.864722
# 6   -67.973056
# 7   -71.190278
# 8   -71.495833
# 9   -71.508889
# Name: lng, dtype: float64

# %% [markdown]
# ## 📌 Paso 1.Vamos a generar un mapa **base** para luego agregar los puntos
# * Esta función configura un mapa para mostrar de la República Argentina, realizados por [Instituto Geográfico Nacional](https://www.ign.gob.ar/)
# * ¿Sabemos qué es una funciòn?

# %%
def generar_mapa():
    attr = (
        '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> '
        'contributors, &copy; <a href="https://cartodb.com/attributions">CartoDB</a>'
    )

    tiles = 'https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png'
    m = folium.Map(
        location=(-33.457606, -65.346857),
        control_scale=True,
        zoom_start=5,
        name='es',
        tiles=tiles,
        attr=attr
    )
    return m

# %% [markdown]
# Usamos la función **generar_mapa** para tener nuestro mapa base

# %%
mapa = generar_mapa()
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c63534bab20cb8a7a2ca4f75b32e4e51 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c63534bab20cb8a7a2ca4f75b32e4e51&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c63534bab20cb8a7a2ca4f75b32e4e51 = L.map(
#                 &quot;map_c63534bab20cb8a7a2ca4f75b32e4e51&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;name&quot;: &quot;es&quot;,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_c63534bab20cb8a7a2ca4f75b32e4e51);
#
#
#
#
#
#             var tile_layer_64fd0dc49b63f27b8be29656b968f3f8 = L.tileLayer(
#                 &quot;https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u0026copy; \u003ca href=\&quot;https://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_64fd0dc49b63f27b8be29656b968f3f8.addTo(map_c63534bab20cb8a7a2ca4f75b32e4e51);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# La variable **mapa** es nuestro mapa **base**

# %% [markdown]
# ## 📌 Paso 2. Definimos la función para poder agregar los puntos:
# En la celda de abajo pusimos el código de la función que permnite agregar los puntos:
#
# * la función **agregar_marca_lago** recibe cada fila e indicamos  los puntos que se encuentran en las columnas de las **coordenadas** de esta forma.
# ```python
# [row['latitud'], row['longitud']],
# ```
# * queremos que muestre el nombre del lago cuando hacemos clic sobre cada icono, ponemos el nombre de la columna **Nombre**,  donde se encuentra **ese dato**.
# ```python
# popup=row['Nombre']
# ```

# %%
def agregar_marca_lago(row):
    folium.Marker(
        [row['lat'], row['lng']],
        popup=row['Nombre'],
        icon=folium.Icon()
        ).add_to(mapa)

# %% [markdown]
# ## 📌 Paso 3. Agregamos los puntos al mapa:

# %% [markdown]
# En la celda de abajo pusimos el código para poder agregar los puntos,  lo más importante para tener en cuenta:
# * el nombre de la variable que contiene los datos de los lagos **lagos** y para que agregue los puntos usamos:
#     * ```python
#       lagos.apply(nombre_funcion, axis=1)
#       ```
# * por úlitmo, mostramos el mapa, escribiendo el nombre de la variable del mapa.

# %%
lagos.apply(agregar_marca_lago, axis=1)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e5dee6290b6ff6cefb30030f85601e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e5dee6290b6ff6cefb30030f85601e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e5dee6290b6ff6cefb30030f85601e9 = L.map(
#                 &quot;map_0e5dee6290b6ff6cefb30030f85601e9&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;name&quot;: &quot;es&quot;,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_0e5dee6290b6ff6cefb30030f85601e9);
#
#
#
#
#
#             var tile_layer_4f861c49161bfdc5e25e102cabfbf145 = L.tileLayer(
#                 &quot;https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u0026copy; \u003ca href=\&quot;https://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4f861c49161bfdc5e25e102cabfbf145.addTo(map_0e5dee6290b6ff6cefb30030f85601e9);
#
#
#             tile_layer_4f861c49161bfdc5e25e102cabfbf145.addTo(map_0e5dee6290b6ff6cefb30030f85601e9);
#
#
#             var marker_10913f22513434deb2c8d9b64eaa4e9e = L.marker(
#                 [-50.24805555555556, -72.64527777777778],
#                 {
# }
#             ).addTo(map_0e5dee6290b6ff6cefb30030f85601e9);
#
#
#             var icon_651d410e1230c41573a264cd17901ac6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_19f464ba07abf5de3672bd9b14eb4efb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82c7a4ef7bcee38a03d2708011a5c506 = $(`&lt;div id=&quot;html_82c7a4ef7bcee38a03d2708011a5c506&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Argentino&lt;/div&gt;`)[0];
#                 popup_19f464ba07abf5de3672bd9b14eb4efb.setContent(html_82c7a4ef7bcee38a03d2708011a5c506);
#
#
#
#         marker_10913f22513434deb2c8d9b64eaa4e9e.bindPopup(popup_19f464ba07abf5de3672bd9b14eb4efb)
#         ;
#
#
#
#
#                 marker_10913f22513434deb2c8d9b64eaa4e9e.setIcon(icon_651d410e1230c41573a264cd17901ac6);
#
#
#             var marker_d1810fd406d8142843b915f52ebf0cab = L.marker(
#                 [-49.62416666666667, -72.495],
#                 {
# }
#             ).addTo(map_0e5dee6290b6ff6cefb30030f85601e9);
#
#
#             var icon_1eb9aae766912faddc687bfb215d4c13 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2b19df8e0c755c6ecc938b4f9d2533a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97d98a29242120a60b125d12e02013c3 = $(`&lt;div id=&quot;html_97d98a29242120a60b125d12e02013c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Viedma&lt;/div&gt;`)[0];
#                 popup_2b19df8e0c755c6ecc938b4f9d2533a3.setContent(html_97d98a29242120a60b125d12e02013c3);
#
#
#
#         marker_d1810fd406d8142843b915f52ebf0cab.bindPopup(popup_2b19df8e0c755c6ecc938b4f9d2533a3)
#         ;
#
#
#
#
#                 marker_d1810fd406d8142843b915f52ebf0cab.setIcon(icon_1eb9aae766912faddc687bfb215d4c13);
#
#
#             var marker_eff34a4631d65a751be4214d809ec691 = L.marker(
#                 [-40.85444444444445, -71.61611111111111],
#                 {
# }
#             ).addTo(map_0e5dee6290b6ff6cefb30030f85601e9);
#
#
#             var icon_82588ef0ee29136d407c4dd903091cc4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_030af91a2767555df5245e66dcfdc2f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ba27399f672fbcbb3c021b0944789ec = $(`&lt;div id=&quot;html_9ba27399f672fbcbb3c021b0944789ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Nahuel Huapi&lt;/div&gt

# %% [markdown]
# ## Mostrar en un mapa los lagos de Chubut

# %%
chubut = lagos[lagos["Ubicación"] == "Chubut"]

# %%
mapa_chubut = generar_mapa()

# %%
def agregar_marca_lago_chubut(row):
    folium.Marker(
        [row['lat'], row['lng']],
        popup=row['Nombre'],
        icon=folium.Icon()
    ).add_to(mapa_chubut)

chubut.apply(agregar_marca_lago_chubut, axis=1)

mapa_chubut
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e43652b83b0d8e2d4e31be9406fe48c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e43652b83b0d8e2d4e31be9406fe48c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e43652b83b0d8e2d4e31be9406fe48c = L.map(
#                 &quot;map_4e43652b83b0d8e2d4e31be9406fe48c&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;name&quot;: &quot;es&quot;,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_4e43652b83b0d8e2d4e31be9406fe48c);
#
#
#
#
#
#             var tile_layer_1dabe4ed695b96685f6a63d9d8331092 = L.tileLayer(
#                 &quot;https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u0026copy; \u003ca href=\&quot;https://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1dabe4ed695b96685f6a63d9d8331092.addTo(map_4e43652b83b0d8e2d4e31be9406fe48c);
#
#
#             var marker_8d5764ee34a3a9a5d7c6cfb1239f59b9 = L.marker(
#                 [-45.414722222222224, -69.19777777777779],
#                 {
# }
#             ).addTo(map_4e43652b83b0d8e2d4e31be9406fe48c);
#
#
#             var icon_32489451826ed0515e07b0f867238c4f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_84550ff02875c50c3eabdf930c3f83c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e7aa822bc43c809cce3ff6ff148eb3f = $(`&lt;div id=&quot;html_9e7aa822bc43c809cce3ff6ff148eb3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Musters&lt;/div&gt;`)[0];
#                 popup_84550ff02875c50c3eabdf930c3f83c7.setContent(html_9e7aa822bc43c809cce3ff6ff148eb3f);
#
#
#
#         marker_8d5764ee34a3a9a5d7c6cfb1239f59b9.bindPopup(popup_84550ff02875c50c3eabdf930c3f83c7)
#         ;
#
#
#
#
#                 marker_8d5764ee34a3a9a5d7c6cfb1239f59b9.setIcon(icon_32489451826ed0515e07b0f867238c4f);
#
#
#             var marker_f65ed839261d5d1badcf0375eff8b1f0 = L.marker(
#                 [-44.921388888888885, -71.49583333333334],
#                 {
# }
#             ).addTo(map_4e43652b83b0d8e2d4e31be9406fe48c);
#
#
#             var icon_0847d3c5b7ced7f68b937a182e667dcf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4915cc3f724cbf80509a0d71e087a68b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a24baa3a373b37989250d6b2d8aa379 = $(`&lt;div id=&quot;html_8a24baa3a373b37989250d6b2d8aa379&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Fontana&lt;/div&gt;`)[0];
#                 popup_4915cc3f724cbf80509a0d71e087a68b.setContent(html_8a24baa3a373b37989250d6b2d8aa379);
#
#
#
#         marker_f65ed839261d5d1badcf0375eff8b1f0.bindPopup(popup_4915cc3f724cbf80509a0d71e087a68b)
#         ;
#
#
#
#
#                 marker_f65ed839261d5d1badcf0375eff8b1f0.setIcon(icon_0847d3c5b7ced7f68b937a182e667dcf);
#
#
#             var marker_19ed9a999224352e52c1fbf63a5534ae = L.marker(
#                 [-44.85916666666667, -71.82],
#                 {
# }
#             ).addTo(map_4e43652b83b0d8e2d4e31be9406fe48c);
#
#
#             var icon_1dbdae1d156daa69a9521d02a890cad9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2a152c11ffda2e67485439323c923311 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb07d29bb06502339b48b174189d2f29 = $(`&lt;div id=&quot;html_fb07d29bb06502339b48b174189d2f29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago La Plata&lt;/div&gt;`)[0];
#                 popup_2a152c11ffda2e67485439323c923311.setContent(html_fb07d29bb06502339b48b174189d2f29);

# %% [markdown]
# ## Mostrar los lagos con iconos de colores según su tamaño

# %% [markdown]
# * ¿En qué columna están con valores categorizados los tamaños de los lagos?
# * ¿Cuáles son los tamaños?

# %%
lagos.columns
# Out:
# Index(['Nombre', 'Ubicación', 'Superficie (km²)', 'Profundidad máxima (m)',
#        'Profundidad media (m)', 'Coordenadas', 'Sup Tamaño', 'Latitud en GMS',
#        'Longitud en GMS', 'lat', 'lng'],
#       dtype='object')

# %%
tamaño = lagos['Sup Tamaño'].head(10)
tamaño
# Out:
# 0    grande
# 1    grande
# 2    grande
# 3    grande
# 4    grande
# 5    grande
# 6    grande
# 7    grande
# 8    grande
# 9    grande
# Name: Sup Tamaño, dtype: object

# %%
lagos['Sup Tamaño'].unique()
# Out:
# array(['grande', 'medio', 'chico'], dtype=object)

# %%
mapa_col = generar_mapa()

# %%
def agregar_marca_lago(row):
    colores_tamaño = {'grande': 'blue', 'medio': 'green', 'chico': 'red'}
    color = colores_tamaño.get(row['Sup Tamaño'], 'gray')
    folium.CircleMarker(
        location=[row['lat'], row['lng']],
        radius=6,
        color=color,
        fill=True,
        popup=row['Nombre']
        ).add_to(mapa_col)

# %%
lagos.apply(agregar_marca_lago, axis=1)
mapa_col
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56d51f760c1e5e76fef0a42274dd5cf8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56d51f760c1e5e76fef0a42274dd5cf8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56d51f760c1e5e76fef0a42274dd5cf8 = L.map(
#                 &quot;map_56d51f760c1e5e76fef0a42274dd5cf8&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;name&quot;: &quot;es&quot;,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_56d51f760c1e5e76fef0a42274dd5cf8);
#
#
#
#
#
#             var tile_layer_2a616aa93a5fe3cefd7314ed055cfd59 = L.tileLayer(
#                 &quot;https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u0026copy; \u003ca href=\&quot;https://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a616aa93a5fe3cefd7314ed055cfd59.addTo(map_56d51f760c1e5e76fef0a42274dd5cf8);
#
#
#             var circle_marker_40f96811861fd644deb2da6c2c3788c3 = L.circleMarker(
#                 [-50.24805555555556, -72.64527777777778],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_56d51f760c1e5e76fef0a42274dd5cf8);
#
#
#         var popup_cc9a7fa4947475022e97bc63140cb015 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_acef1c24e49fe42ad19db96871cb3283 = $(`&lt;div id=&quot;html_acef1c24e49fe42ad19db96871cb3283&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Argentino&lt;/div&gt;`)[0];
#                 popup_cc9a7fa4947475022e97bc63140cb015.setContent(html_acef1c24e49fe42ad19db96871cb3283);
#
#
#
#         circle_marker_40f96811861fd644deb2da6c2c3788c3.bindPopup(popup_cc9a7fa4947475022e97bc63140cb015)
#         ;
#
#
#
#
#             var circle_marker_42e104ce50bf048e3e27f8ed66ccc9d7 = L.circleMarker(
#                 [-49.62416666666667, -72.495],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_56d51f760c1e5e76fef0a42274dd5cf8);
#
#
#         var popup_dd9c614c06e0801950e2a29e4f4a2488 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c070df60f2aebb97cb4bdb5e014e2bc2 = $(`&lt;div id=&quot;html_c070df60f2aebb97cb4bdb5e014e2bc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Viedma&lt;/div&gt;`)[0];
#                 popup_dd9c614c06e0801950e2a29e4f4a2488.setContent(html_c070df60f2aebb97cb4bdb5e014e2bc2);
#
#
#
#         circle_marker_42e104ce50bf048e3e27f8ed66ccc9d7.bindPopup(popup_dd9c614c06e0801950e2a29e4f4a2488)
#         ;
#
#
#
#
#             var circle_marker_7f81ac816b87c9e792b37852b62fd3ae = L.circleMarker(
#                 [-40.85444444444445, -71.61611111111111],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_56d51f760c1e5e76fef0a42274dd5cf8);
#
#
#         var popup_879bb5e606af9d4edaef0b7b34ecf874 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f6e59063bacb659752962b4e33479d8 = $(`&lt;div id=&quot;html_5f6e59063bacb659752962b4e33479d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Nahuel Huapi&lt;/div&gt;`)[0];
#                 popup_879

# %%
mapa_colores = generar_mapa()

def agregar_marca_lago_colores(row):
    colores_tamaño = {'grande': 'blue', 'medio': 'green', 'chico': 'red'}
    color = colores_tamaño.get(row['Sup Tamaño'], 'gray')

    folium.Marker(
        location=[row['lat'], row['lng']],
        popup=row['Nombre'],
        icon=folium.Icon(color=color)
    ).add_to(mapa_colores)

lagos.apply(agregar_marca_lago_colores, axis=1)

mapa_colores
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6857a0c4ce5ac2e051d2e43dda1bcd0e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6857a0c4ce5ac2e051d2e43dda1bcd0e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6857a0c4ce5ac2e051d2e43dda1bcd0e = L.map(
#                 &quot;map_6857a0c4ce5ac2e051d2e43dda1bcd0e&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;name&quot;: &quot;es&quot;,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_6857a0c4ce5ac2e051d2e43dda1bcd0e);
#
#
#
#
#
#             var tile_layer_9f116b9f0294253f313646a023b185c8 = L.tileLayer(
#                 &quot;https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u0026copy; \u003ca href=\&quot;https://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9f116b9f0294253f313646a023b185c8.addTo(map_6857a0c4ce5ac2e051d2e43dda1bcd0e);
#
#
#             var marker_fecab137a576a7661aec98f41e1d7e15 = L.marker(
#                 [-50.24805555555556, -72.64527777777778],
#                 {
# }
#             ).addTo(map_6857a0c4ce5ac2e051d2e43dda1bcd0e);
#
#
#             var icon_c2a8f40b9149c91287f33a68c379e792 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6b5cf288b0ffa378b35e53b88298f67c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a6b54e5302c44a901b065d4c3402b60 = $(`&lt;div id=&quot;html_2a6b54e5302c44a901b065d4c3402b60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Argentino&lt;/div&gt;`)[0];
#                 popup_6b5cf288b0ffa378b35e53b88298f67c.setContent(html_2a6b54e5302c44a901b065d4c3402b60);
#
#
#
#         marker_fecab137a576a7661aec98f41e1d7e15.bindPopup(popup_6b5cf288b0ffa378b35e53b88298f67c)
#         ;
#
#
#
#
#                 marker_fecab137a576a7661aec98f41e1d7e15.setIcon(icon_c2a8f40b9149c91287f33a68c379e792);
#
#
#             var marker_a05f84c802c6d489eef0d94b8b309f54 = L.marker(
#                 [-49.62416666666667, -72.495],
#                 {
# }
#             ).addTo(map_6857a0c4ce5ac2e051d2e43dda1bcd0e);
#
#
#             var icon_ff1bd78f2dcbd6ebffe99103421122d4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9ac0447f549a6d04883fd4c9eff3927e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62c183b478e3665a8449ebaf0b614795 = $(`&lt;div id=&quot;html_62c183b478e3665a8449ebaf0b614795&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Viedma&lt;/div&gt;`)[0];
#                 popup_9ac0447f549a6d04883fd4c9eff3927e.setContent(html_62c183b478e3665a8449ebaf0b614795);
#
#
#
#         marker_a05f84c802c6d489eef0d94b8b309f54.bindPopup(popup_9ac0447f549a6d04883fd4c9eff3927e)
#         ;
#
#
#
#
#                 marker_a05f84c802c6d489eef0d94b8b309f54.setIcon(icon_ff1bd78f2dcbd6ebffe99103421122d4);
#
#
#             var marker_449db00ec31d32641ce41e8429a541b3 = L.marker(
#                 [-40.85444444444445, -71.61611111111111],
#                 {
# }
#             ).addTo(map_6857a0c4ce5ac2e051d2e43dda1bcd0e);
#
#
#             var icon_102d3cd34b82429c117202a38ba2b5bf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9185b4b20d2ce5975e17a5b132d15a79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61918c46d4ca2182a5fa4ea36808639e = $(`&lt;div id=&quot;html_61918c46d4ca2182a5fa4ea36808639e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Nahuel Huapi&lt;/div&gt;`)[0];
#                 popup_9185b4b20d2ce5975e17a5b132d15a79.setContent(html_61918c46d4ca2182a5fa4ea36808639e);
